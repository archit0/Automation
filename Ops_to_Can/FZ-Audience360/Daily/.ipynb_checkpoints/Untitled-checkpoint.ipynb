# %%
import pandas as pd
import numpy as np
import psycopg2
import time
import datetime
import sys

print("Execution start")
# database credentials
database1 = "opsfeaturizer"
database2 = "alchemy"
db_user = "slickdeal_dev_user"
db_password = "UfHK3bnMy78siAie"
db_host = "127.0.0.1"
db_port = "5439"
# Out:
# Execution start

# %%
conn1 = psycopg2.connect(
    dbname=database1,
    user=db_user,
    password=db_password,
    host=db_host,
    port=db_port
)

conn2 = psycopg2.connect(
    dbname=database2,
    user=db_user,
    password=db_password,
    host=db_host,
    port=db_port
)

# %%
user_df = pd.read_sql_query('select id from segment', con=conn2)
value_df = pd.read_sql_query('select * from segment_attribute_time_value where segment_attribute_id in (14,15,16,17) and attribute_granularity_id = 3;', con=conn2)
attr_df = pd.read_sql_query('select id, name from segment_attribute where id in (14,15,16,17);', con=conn2)

# %%
def relationize(f_name, row):
    key = 'value_num_of_engagements_per_device'
    expr = row[key]
    expr = json.loads(expr)
    return expr.get(f_name, "0")


columns = ['segment_id', 'date_index', 'year', 'month', 'week', 'weekday',
       'value_num_of_engagements_per_device', 'channel']
dfz = pd.DataFrame(columns=columns)
final_df.shape

# channels = ["Mobile", "Tablet", "Desktop"]
# for chan in channels:
# #     dfz["channel"] = dfz.apply(lambda x: chan)
#     dfz["value"] = dfz.apply(lambda x:  relationize(chan, x), axis=1)
    
    
# #     df_mobile = df_mobile.apply(lambda x:  relationize(chan, x[key]), axis=1)
# #     df_tablet = df_mobile.apply(lambda x:  relationize(chan, x[key]), axis=1)
# #     df_desktop = df_mobile.apply(lambda x:  relationize(chan, x[key]), axis=1)

# #     dfz["channel"] = dfz.apply(lambda x:  relationize("Mobile", x[key]), axis=1)



# dfz
# Out:
# (7353, 7)

# %%
df10 = pd.read_sql("select * from content_consumed_by_channel where date_index='20190119' limit 500;", con=conn1)

# %%
mdf = df10

# %%
mdf
# Out:
#                       id               user_id     y  m  w  dw  date_index  \
# 0   -9223372036153067412  -9223372035814999697  2019  1  3   6    20190119
# 1   -9223372036701662370  -9223372035814999698  2019  1  3   6    20190119
# 2   -9223372035819267661  -9223372035814999714  2019  1  3   6    20190119
# 3   -9223372036222441556  -9223372035814999715  2019  1  3   6    20190119
# 4   -9223372036381168603  -9223372035814999745  2019  1  3   6    20190119
# ..                   ...                   ...   ... .. ..  ..         ...
# 495 -9223372036278884251  -9223372035815006416  2019  1  3   6    20190119
# 496 -9223372035806179853  -9223372035815006426  2019  1  3   6    20190119
# 497 -9223372036345165936  -9223372035815006440  2019  1  3   6    20190119
# 498 -9223372036571063686  -9223372035815006446  2019  1  3   6    20190119
# 499 -9223372036145149119  -9223372035815006462  2019  1  3   6    20190119
#
#      channel  number_of_footsteps               created_time  \
# 0    Desktop                    1 2019-09-25 06:47:00.343632
# 1     Mobile                    1 2019-09-25 06:47:00.343632
# 2    Desktop                    1 2019-09-25 06:47:00.343632
# 3     Mobile                    1 2019-09-25 06:47:00.343632
# 4    Desktop                    1 2019-09-25 06:47:00.343632
# ..       ...                  ...                        ...
# 495  Desktop                    3 2019-09-25 06:47:00.343632
# 496  Desktop                    1 2019-09-25 06:47:00.343632
# 497  Desktop                    1 2019-09-25 06:47:00.343632
# 498  Desktop                    9 2019-09-25 06:47:00.343632
# 499  Desktop                    1 2019-09-25 06:47:00.343632
#
#           modified_time
# 0   2019-09-25 06:47:00
# 1   2019-09-25 06:47:00
# 2   2019-09-25 06:47:00
# 3   2019-09-25 06:47:00
# 4   2019-09-25 06:47:00
# ..                  ...
# 495 2019-09-25 06:47:00
# 496 2019-09-25 06:47:00
# 497 2019-09-25 06:47:00
# 498 2019-09-25 06:47:00
# 499 2019-09-25 06:47:00
#
# [500 rows x 11 columns]

# %%
user_data_dictionary = {}
for index, row in mdf.iterrows():
    user_id, channel, foot = row['user_id'], row['channel'], row['number_of_footsteps']
    prev = user_data_dictionary.get(user_id, {})
    prev[channel] = foot
    user_data_dictionary[user_id] = prev

# %%
dfN = user_data_dictionary

# %%
user_data_dictionary['-9223372035815002130']
# Out:
# {'Mobile': 1}

# %%
import json

# %%
json.dumps(user_data_dictionary['-9223372035815002130'])
# Out:
# '{"Mobile": 1}'

# %%
user_df = pd.read_sql_query('select id from segment', con=conn2)
value_df = pd.read_sql_query('select * from segment_attribute_time_value where segment_attribute_id in (1,2,3,4,5,6,9) and attribute_granularity_id = 1;', con=conn2)
attr_df = pd.read_sql_query('select id, name from segment_attribute where id in (1,2,3,4,5,6,9);', con=conn2)

final_df = pd.merge(attr_df, value_df, how='left', left_on='id', right_on='segment_attribute_id')
final_df = pd.pivot_table(final_df, columns=['name'], index=['segment_id', 'date_index', 'year', 'month', 'week','weekday'], values=['value'], aggfunc=max).reset_index()
final_df.columns =['_'.join(col).rstrip('_') for col in final_df.columns.values]
df_final= final_df.rename(columns={'year':'y', 'month':'m', 'week':'w', 'weekday':'dw','value_sum_net_transaction_amount':'total_transaction_amount','value_avg_net_transaction_amount':'avg_transaction_amount','value_transactions_frequency':'transactions_frequency','value_sum_net_total_commission':'total_commission','value_avg_net_total_commission':'avg_total_commission','value_average_total_transaction_amount_per_customer':'average_total_transaction_amount_per_customer','value_average_total_commission_per_customer':'average_total_commission_per_customer'})

# %%
df_final.columns
# Out:
# Index(['segment_id', 'date_index', 'y', 'm', 'w', 'dw',
#        'average_total_commission_per_customer',
#        'average_total_transaction_amount_per_customer', 'avg_total_commission',
#        'avg_transaction_amount', 'total_commission',
#        'total_transaction_amount', 'transactions_frequency'],
#       dtype='object')

# %%
df1=pd.merge(df_final, user_df, how='left', left_on='segment_id', right_on='id')
df1 = df1[['date_index', 'y', 'm', 'w', 'dw', 'segment_id','total_transaction_amount', 'avg_transaction_amount', 'transactions_frequency', 'total_commission', 'avg_total_commission', 'average_total_transaction_amount_per_customer', 'average_total_commission_per_customer' ]]

# %%
df1.columns
# Out:
# Index(['date_index', 'y', 'm', 'w', 'dw', 'segment_id',
#        'total_transaction_amount', 'avg_transaction_amount',
#        'transactions_frequency', 'total_commission', 'avg_total_commission',
#        'average_total_transaction_amount_per_customer',
#        'average_total_commission_per_customer'],
#       dtype='object')

# %%
 ('avg_transaction_amount', 
  'avg_total_commission', 
  'average_total_transaction_amount_per_customer', 
  'average_total_commission_per_customer'

# %%
final_df = pd.merge(attr_df, value_df, how='left', left_on='id', right_on='segment_attribute_id')
final_df = pd.pivot_table(final_df, columns=['name'], index=['segment_id', 'date_index', 'year', 'month', 'week','weekday'], values=['value'], aggfunc=max).reset_index()
final_df.columns =['_'.join(col).rstrip('_') for col in final_df.columns.values]
df_final= final_df.rename(columns={'year':'y', 'month':'m', 'week':'w', 'weekday':'dw','value_content_consumed_threads_viewed':'total_thread_view','value_content_consumed_searches':'total_searches','value_average_thread_views_per_user':'average_thread_views_per_user','value_average_searches_per_user':'average_searches_per_user'})

# %%
df1=pd.merge(df_final, user_df, how='left', left_on='segment_id', right_on='id')
df1 = df1[['date_index', 'y', 'm', 'w', 'dw','segment_id','total_thread_view','total_searches','average_thread_views_per_user','average_searches_per_user' ]]
df1['average_thread_views_per_user'] = df1['average_thread_views_per_user'].astype(float)
df1['average_searches_per_user'] = df1['average_searches_per_user'].astype(float)
df1.sort_values(['segment_id', 'y', 'm', 'w', 'dw', 'date_index'], ascending = True, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-84-cb0c025036d4> in <module>
# ----> 1 df1=pd.merge(df_final, user_df, how='left', left_on='segment_id', right_on='id')
#       2 df1 = df1[['date_index', 'y', 'm', 'w', 'dw','segment_id','total_thread_view','total_searches','average_thread_views_per_user','average_searches_per_user' ]]
#       3 df1['average_thread_views_per_user'] = df1['average_thread_views_per_user'].astype(float)
#       4 df1['average_searches_per_user'] = df1['average_searches_per_user'].astype(float)
#       5 df1.sort_values(['segment_id', 'y', 'm', 'w', 'dw', 'date_index'], ascending = True, inplace = True)
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      80         copy=copy,
#      81         indicator=indicator,
# ---> 82         validate=validate,
#      83     )
#      84     return op.get_result()
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     625             self.right_join_keys,
#     626             self.join_names,
# --> 627         ) = self._get_merge_keys()
#     628
#     629         # validate the merge keys dtypes. We may need to coerce
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#     987                         right_keys.append(rk)
#     988                     if lk is not None:
# --> 989                         left_keys.append(left._get_label_or_level_values(lk))
#     990                         join_names.append(lk)
#     991                     else:
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1773             values = self.axes[axis].get_level_values(key)._values
#    1774         else:
# -> 1775             raise KeyError(key)
#    1776
#    1777         # Check for duplicates
#
# KeyError: 'segment_id'

# %%
df_final
# Out:
# Empty DataFrame
# Columns: [i_n_d_e_x]
# Index: []

# %%
final_df
# Out:
# Empty DataFrame
# Columns: [i_n_d_e_x]
# Index: []
